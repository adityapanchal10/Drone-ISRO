# %%
import geopandas
import matplotlib.pyplot as plt

df = geopandas.read_file("railways.shp")

# %%
df.plot()

# %%
df2 = df.to_json()

# %%
df2
# Out:
# '{"type": "FeatureCollection", "features": [{"id": "0", "type": "Feature", "properties": {"name": null, "osm_id": 4003706, "type": "industrial"}, "geometry": {"type": "LineString", "coordinates": [[5.1004862, 52.0896302], [5.1003149, 52.0896064], [5.1003197, 52.0895351], [5.1004957, 52.0895541], [5.1004862, 52.0896302]]}}, {"id": "1", "type": "Feature", "properties": {"name": null, "osm_id": 4004268, "type": "light_rail"}, "geometry": {"type": "LineString", "coordinates": [[5.1071796, 52.0920986], [5.1065451, 52.091883], [5.1061073, 52.0916966], [5.1059347, 52.091584], [5.1058312, 52.0914931], [5.1057423, 52.0914225], [5.1056553, 52.0913082], [5.1055936, 52.0911182], [5.1053897, 52.0906392], [5.1051741, 52.0903415], [5.1049784, 52.0901411], [5.1047752, 52.0899613], [5.1046714, 52.0898871], [5.1044038, 52.0896918], [5.1040895, 52.0895102], [5.1039779, 52.0894494], [5.1034601, 52.0891984], [5.1030974, 52.0890579], [5.101522, 52.0885368], [5.1011661, 52.0883647], [5.1008993, 52.0881218]
# ...

# %%
import geojsonio
geojsonio.display(df2)
# Out:
# ---------------------------------------------------------------------------
# WantWriteError                            Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in _send_until_done(self, data)
#     319             try:
# --> 320                 return self.connection.send(data)
#     321             except OpenSSL.SSL.WantWriteError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\OpenSSL\SSL.py in send(self, buf, flags)
#    1736         result = _lib.SSL_write(self._ssl, buf, len(buf))
# -> 1737         self._raise_ssl_error(self._ssl, result)
#    1738         return result
#
# C:\ProgramData\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1623         elif error == _lib.SSL_ERROR_WANT_WRITE:
# -> 1624             raise WantWriteError()
#    1625         elif error == _lib.SSL_ERROR_ZERO_RETURN:
#
# WantWriteError:
#
# ...
